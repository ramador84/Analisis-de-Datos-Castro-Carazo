# %% [markdown]
# <center><b><h1 style="color:#000080">CAMBIO CLIMATICO</h1></b></center>

# %% [markdown]
# <center><b><h2 style="color:#000080">INTRODUCCION</h2></b></center>

# %% [markdown]
# <h4>Durante miles de años los seres humanos basaron su desarrollo en la agricultura y la caza. Y las principales fuentes de emisión de CO₂ estaban vinculadas a una sociedad artesanal y rural.</h4>
#
# <h4>A partir de la segunda mitad del siglo XVIII, la máquina de vapor lo cambia todo. A la quema de biomasa para generar energía se le suma el carbón como principal alimento de la Revolución Industrial, primero en el Reino Unido y luego en toda la Europa. El carbón sigue siendo hoy la principal fuente de emisiones de dióxido de carbono</h4>
#
# <h4>El gran salto se produce después de la Segunda Guerra Mundial. El período de relativa paz unido a más avances tecnológicos y el incremento demográfico dispara también las emisiones de dióxido de carbono. Además, empiezan a reducirse los bosques (sumideros de carbono) y el gas natural se suma al carbón y al petróleo como motores de las economías desarrolladas</h4>
#
# <h4>Las emisiones de CO₂ han seguido aumentando durante este siglo de forma casi ininterrumpida. El crecimiento solo se ha visto frenado por las crisis económicas. En 2015, tras décadas de discusiones, se aprobó el Acuerdo de París, el primer pacto que obliga a todos los países firmantes a presentar planes de recorte de sus emisiones de gases de efecto invernadero.</h4>

# %% [markdown]
# <center><b><h2 style="color:#000080"> QUE ES EL CAMBIO CLIMATICO</h2></b></center>

# %% [markdown]
# <h4>Es la variación estadísticamente significativa, ya sea de las condiciones climáticas medias o de su variabilidad que se mantiene durante un período prolongado (generalmente durante más de diez años).</h4>
#
# <h4>El cambio del clima podría deberse a los procesos naturales internos, las acciones externas o a cambios generados por los seres humanos, de forma duradera, en la composición de la atmósfera o en el uso de la tierra.</h4>

# %% [markdown]
# <center><b><h2 style="color:#000080"> NO ES LO MISMO EL TIEMPO ATMOSFÉRICO Y CLIMA </h2></b></center>

# %% [markdown]
# <h4>El tiempo atmosférico se asocia a las condiciones de la atmósfera en un lugar determinado y para un período corto, normalmente días o semanas.</h4>
#
# <h4>El clima es el promedio del tiempo atmosférico para períodos largos, comúnmente meses, años o más. Se define por los valores medios y la variabilidad de la temperatura, la precipitación y otras variables.</h4>
#
# <h4>En su cuarto informe de Consenso Científico, el Panel Intergubernamental de Expertos en Cambio Climático expresa que se han producido cambios en varios aspectos de la atmósfera y la superficie del planeta que modifican el presupuesto de energía mundial de la Tierra y que, por lo tanto, pueden cambiar el clima. Entre estos cambios se encuentran el aumento de las concentraciones de gases de efecto invernadero que sirven principalmente para aumentar la absorción atmosférica de la radiación emitida por la tierra, y el aumento de los aerosoles(partículas o gotas microscópicas presentes en el aire) que actúan para reflejar o absorber la radiación solar reflejada y cambian las propiedades de las nubes.</h4>

# %% [markdown]
# <center><b><h2 style="color:#000080">El EFECTO INVERNADERO</h2></b></center>

# %% [markdown]
# <h4>En la figura siguiente, la radiación solar calienta la superficie de la tierra porque la atmósfera es “transparente” a los rayos del sol y al calentarse el planeta emite radiación terrestre. Los gases de efecto invernadero que existen en la atmosfera absorben y re-emiten la radiación terrestre (esta radiación es infrarroja, o sea, contiene calor) y la atmósfera se calienta. Gracias a esto, la temperatura de la tierra es de 15°C y no de -18°C, por tanto el efecto invernadero es natural y beneficioso.</h4>

# %% [markdown]
# <center><img SRC="fig1.png"/></center>

# %% [markdown]
# <h4>Sin embargo, lo que está sucediendo es que las diversas actividades humanas han incrementado a cifras preocupantes las concentraciones de estos gases en la atmósfera, dando como resultado la pérdida del equilibrio o balance natural de radiaciones y por tanto, gran parte de las radiaciones emitidas por la tierra en forma de calor (radiación infrarroja), están retornando de nuevo a la tierra, pues los gases de efecto invernadero actúan como una especie de barrera, entre la tierra y la parte superior de la atmósfera.</h4>
#
# <h4>Los Gases de Efecto Invernadero de larga vida, entre los cuales se encuentran el CO2, el metano (CH4) y el óxido nitroso (NO2), persisten en la atmósfera durante períodos de tiempo que van desde décadas hasta siglos o más; por tanto, estos gases influyen en el clima a largo plazo. En la siguiente tabla se muestran las principales características de los gases efecto invernadero</h4>

# %% [markdown]
# <center><b><h2 style="color:#000080">TIPO DE GAS </h2></b></center>

# %%
tg=pd.read_excel('tipo_gas.xlsx')
tg
# Out:
#    #      Nombre del Gas                                  Breve descripción  \
# 0  1  Dióxido de carbono  Se libera desde el interior de la Tierra a tra...
# 1  2              Metano  El metano es producido principalmente a través...
# 2  3       Óxido nitroso  El óxido nitroso (N2O) es producido por proces...
# 3  4               Ozono  En la estratosfera filtra los rayos ultraviole...
# 4  5         Halocarbono  Clorofluorocarbonos: compuestos mayormente de ...
# 5  6           Aerosoles  La variación en la cantidad de aerosoles afect...
#
#                                      Emisión natural  \
# 0  Respiración, descomposición de materia orgánic...
# 1  Naturalmente a través de la descomposición de ...
# 2       Naturalmente en océanos y bosques lluviosos.
# 3  Se forma a través de reacciones fotoquímicas q...
# 4  Existen fuentes naturales en las que se produc...
# 5  Las fuentes naturales se calculan que son 4 a ...
#
#             Emisión antropogénica (de origen humano)  \
# ...

# %% [markdown]
# <center><b><h2 style="color:#000080">IMPACTOS DE LA VARIABILIDAD CLIMATICA Y EL CAMBIO CLIMATICO </h2></b></center>

# %% [markdown]
# <h4>La variabilidad del clima se refiere a las variaciones en el estado medio y otros datos estadísticos del clima (como las desviaciones típicas, la ocurrencia de fenómenos extremos, etc.), en todas las escalas temporales y espaciales, más allá de fenómenos meteorológicos determinados. La variabilidad del clima se refiere a las variaciones en el estado medio y otros datos estadísticos del clima. Un ejemplo de variabilidad climática son los episodios de El Niño y La Niña..</h4>
#
# <h3>Impactos sobre Biodiversidad.</h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>Reducción de la biodiversidad volviendo los hábitats climáticamente inapropiados.</li>
# <li>La deforestación, pérdida de hábitats lo que reduce las poblaciones y distribución de las especies de la vida silvestre.</li>
# <li>Las sequias prolongadas que provocan escasez de agua, mortalidad en algunas plantas y animales, migración de especies o incremento de sus poblaciones, lo que provoca desequilibrio en los sistemas naturales, incremento de algunas especies como las ratas a niveles de plagas, enfermedades, la reducción de refugios y fuentes de alimento para los animales silvestres.</li>
# </ol>
#
# <h3>Impactos sobre los Recursos Hídricos.<h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>Incremento en los riesgos de contaminación de los cuerpos de agua, debido a prácticas culturales del uso excesivo de productos fitosanitarios en la agricultura.</li>
# <li>Acelerado proceso de sedimentación en las fuentes hídricas superficiales, debido al intenso proceso de deforestación y pérdida de la cobertura vegetal unido a las prácticas ganaderas extensivas.</li>
# <li>Agotamiento estacional de algunas reservas de agua subterráneas, debido a que la demanda ha superado la oferta de los acuíferos en el corredor seco.</li>
# <li>Contaminación de aguas subterráneas en algunos acuíferos costeros, debido a la intrusión salina.</li>
# </ol>
#
# <h3>Sector productivo/sector agropecuario.</h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>Los impactos del cambio climático en sistemas agropecuarios, bajo los diferentes escenarios climáticos, tienen una tendencia a la disminución en los rendimientos de los cultivos de frijol y maíz generalizada para el territorio nacional y más vulnerable para los cantones con características agro ecológicas críticas (bajas precipitaciones y altas temperaturas).</li>
# <li>Aumento de la erosión de los suelos.</li>
# <li>Pérdida de nutrientes, debido a inadecuadas prácticas culturales del manejo de los suelos e intensas lluvias.</li>
# <li>Pérdidas estacionales de cultivo, debido a la variabilidad climática.</li>
# </ol>
#
# <h3>Áreas protegidas y zonas marino costeras.</h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>La migración de especies de la vida silvestre marina y cambio en los patrones de distribución.</li>
# <li>Disminución de los rendimientos del recurso pesquero, especialmente las de mayor comercialización.</li>
# <li>Incremento en la sedimentación de las costas.</li>
# <li>Disminución de especies de agua dulce y marinas por incremento en la temperatura del agua.</li>
# <li>Reducción del número de pescadores y del número de embarcaciones dedicadas a las faenas de pesca artesanal.</li>
# <li>Dificultad de la navegación en cursos de ríos por sequías.</li>
# <li>Cambios en la geomorfología en costas y playas.</li>
# <li>Riesgos sobre infraestructuras costeras.</li>
# </ol>
#
#
# <h3>Salud Humana.</h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>Aumento de la morbilidad debido a enfermedades permanentes asociadas a perturbaciones ambientales inducidas por la variabilidad climática (aquellas transmitidas por vectores).</li>
# <li>Aumento de los costos de salud e intervención en la atención a la salud.</li>
# <li>Incrementos de enfermedades asociadas con la desnutrición.</li>
# <li>Aparición de nuevas enfermedades por migración de vectores y reemergencia de otras enfermedades ya controladas.</li>
# </ol>
#
# <h3>Infraestructuras y asentamiento humano.</h3>
#
# <ol style="list-style-type:lower-alpha">
# <li>Daños a la superficie de rodamiento en carreteras y la infraestructura vial rural.</li>
# <li>Incremento de los costos en infraestructuras.</li>
# <li>Aumento en los costos de mantenimiento vial.</li>
# <li>Afectaciones a la vivienda y al fondo edificado.</li>
# <li>Aumento de riesgos físicos sobre centros poblados</li>
# </ol>

# %% [markdown]
# <h3>Fuente.</h3>
# <a href="https://www.ipcc.ch/">El Panel Intergubernamental sobre el Cambio Climático</a>

# %%
import pandas as pd
import xlrd
import numpy as np   
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import os
import re  #permite utilizar expreciones regulares

# %%
ces=pd.read_excel('consumo_energetico_sector.xlsx')
caso=pd.DataFrame(ces)
ctp=pd.read_excel('consumo_tipo_fuente.xlsx')
gtf=pd.read_excel('generacion_tipo_fuente.xlsx')
hte=pd.read_excel('historico_total_emisiones.xlsx')
ofe=pd.read_excel('oferta.xlsx')

# %%
ces.columns.tolist()
# Out:
# ['Descripcion',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018']

# %%
print(ces.columns.tolist())
# Out:
# ['Descripcion', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']

# %%
ces
# Out:
#                            Descripcion   2010   2011   2012   2013   2014  \
# 0                      Residencial BNE  23382  22139  21586  21366  20603
# 1                        Servicios BNE   6146   6087   6206   6246   6417
# 2                        Comercial BNE   3513   3479   3636   3870   3980
# 3                          Público BNE   3869   3951   4230   4296   4454
# 4                       Transporte BNE  70319  72109  74111  74637  76186
# 5                        Industria BNE  37995  36973  37740  38994  39206
# 6                     Agropecuario BNE   2854   3092   3242   3273   3254
# 7  Consumo no identificado (otros) BNE    953   1106    955   1008   1281
#
#     2015   2016   2017   2018
# 0  20791  20620  20652  19481
# 1   6671   7042   7175   7303
# 2   4114   4306   4322   4464
# 3   4575   4687   4690   4803
# 4  81526  87538  89061  91231
# 5  38368  39728  40047  39262
# 6   3327   3584   3761   3337
# 7   1346   1364   1493   1430

# %%
ces.dtypes
# Out:
# Descripcion    object
# 2010            int64
# 2011            int64
# 2012            int64
# 2013            int64
# 2014            int64
# 2015            int64
# 2016            int64
# 2017            int64
# 2018            int64
# dtype: object

# %%
gf1= ces.groupby(['Descripcion']).cummax()
gf1=gf1.iloc[:,8:9]
#gf1 = gf1.sort_values('2010')
gf1
# Out:
#     2018
# 0  19481
# 1   7303
# 2   4464
# 3   4803
# 4  91231
# 5  39262
# 6   3337
# 7   1430

# %%
sector=('Residencial BNE','Servicios BNE','Comercial BNE','Público BNE','Transporte BNE','Industria BNE','Agropecuario BNE','Consumo no identificado (otros) BNE')

eje_y = gf1['2018'].tolist()


plt.rcdefaults()

fig, ax = plt.subplots()

y_pos = np.arange(len(sector))

plt.barh(y_pos, eje_y, align='center',height=0.9, color= "#FFA07A", alpha=1)

plt.yticks(y_pos, labels=sector)
#plt.invert_yaxis()  # labels read top-to-bottom
plt.xlabel('Consumo de Energia 2018').set_color("#018401")
plt.title('¿Cual es la sector con mayor consumo de Eneria?')

plt.show()

# %%
ces.groupby('Descripcion')['2010','2011','2012','2013','2014','2015','2016','2017','2018'].sum().plot(kind='barh', legend='Reverse')

plt.xlabel("Consumo Energetico",fontsize=1)
plt.ylabel("Sector")
plt.title('¿Cual es el sector con mayor mayor consumo energetico?')
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_12456/4011150418.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ces.groupby('Descripcion')['2010','2011','2012','2013','2014','2015','2016','2017','2018'].sum().plot(kind='barh', legend='Reverse')

# %%
unionArchivos = [ces, ctp]
dato = pd.concat(unionArchivos)    
dato.shape
# Out:
# (26, 10)

# %%
dato
# Out:
#                             Descripcion      2010      2011      2012  \
# 0                       Residencial BNE  23382.00  22139.00  21586.00
# 1                         Servicios BNE   6146.00   6087.00   6206.00
# 2                         Comercial BNE   3513.00   3479.00   3636.00
# 3                           Público BNE   3869.00   3951.00   4230.00
# 4                        Transporte BNE  70319.00  72109.00  74111.00
# 5                         Industria BNE  37995.00  36973.00  37740.00
# 6                      Agropecuario BNE   2854.00   3092.00   3242.00
# 7   Consumo no identificado (otros) BNE    953.00   1106.00    955.00
# 0                        Carbón Mineral     29.89    229.20     91.97
# 1                                 Coque   2675.36   3717.92   3382.79
# 2                                  Leña  13998.14  12839.58  12161.88
# 3                                Bagazo   9836.32   7729.44   8088.95
# ...

# %%
dato.iloc[4]
# Out:
# Descripcion    Transporte BNE
# 2010                  70319.0
# 2011                  72109.0
# 2012                  74111.0
# 2013                  74637.0
# 2014                  76186.0
# 2015                  81526.0
# 2016                  87538.0
# 2017                  89061.0
# 2018                  91231.0
# Name: 4, dtype: object

# %%
dato.iloc[23]
# Out:
# Descripcion      Diesel
# 2010            37366.9
# 2011           37846.49
# 2012           38341.17
# 2013           38437.05
# 2014           39234.72
# 2015           41315.37
# 2016           43900.44
# 2017           44661.06
# 2018           44766.79
# Name: 15, dtype: object

# %%
gf7 = dato.groupby(['Descripcion']).sum()
gf7 = gf7.iloc[:,:10]
#gf1=df_Autos.rename(columns={'make':'Marca'}
gf7
# Out:
#                                          2010      2011      2012      2013  \
# Descripcion
# Agropecuario BNE                      2854.00   3092.00   3242.00   3273.00
# Av-Gas                                  58.09     55.96     54.38     52.24
# Bagazo                                9836.32   7729.44   8088.95   9864.93
# Biogas                                   0.00      2.99      3.03      3.03
# Carbón Mineral                          29.89    229.20     91.97    204.32
# Carbón Vegetal                          41.80     32.34     35.59     38.29
# Casc. de Café                          375.26    407.07    461.19    461.19
# Comercial BNE                         3513.00   3479.00   3636.00   3870.00
# Consumo no identificado (otros) BNE    953.00   1106.00    955.00   1008.00
# Coque                                 2675.36   3717.92   3382.79   3359.27
# Diesel                               37366.90  37846.49  38341.17  38437.05
# ...

# %%
data = ('2010','2011','2012','2013','2014','2015','2016','2017','2018')

dim = len(data[1])
w = 0.75
dimw = w / dim

fig, ax = plt.subplots()
x = np.arange(len(data))
for i in range(len(data[0])):
    y = [d[i] for d in data]
    b = ax.bar(x + i * dimw, y, dimw, bottom=0.001)

plt.xticks(x + dimw / 2, labels=map(str, x))
plt.yscale('log')

ax.set_xlabel('Sector')
ax.set_ylabel('Consumo Energetico')

plt.show()

# %% [markdown]
# <center><b><h2 style="color:#000080">Que podemos Hacer para Revertir El Cambio Climatico</h2></b></center>

# %% [markdown]
# <h4>Ser conscientes del impacto de las emisiones de CO2</h4>
#
# <h5>El calentamiento global causado por el dióxido de carbono (CO2) y otros gases de efecto invernadero (GEI) emitidos por los seres humanos desde la revolución industrial es una realidad constatada. El Acuerdo de la Cumbre del Clima de París (COP 21), firmado por 195 países más la Unión Europea (UE), pretende ser el arranque definitivo para concienciar a la comunidad internacional y a los ciudadanos de que hay que tomar medidas.</h5>

# %% [markdown]
# <h4>Practicar una movilidad sostenible</h4>
# <h5>Si hay una industria que conoce bien impacto ambiental del cambio climático, esa es la industria del Tranpsorte. Por esta razón, los grandes fabricantes presentan cada año alternativas verdes al coche convencional (híbridos y eléctricos). Pero estas opciones son poco absequibles por el momento, la opcion mas proxima es el  transporte público y debemos exigir que haya más y que sea más ecológico. Siempre que sea posible, es preferible ir a pie o en bicicleta en todos los desplazamientos, tanto de ocio como para ir al trabajo. Puedes incluso aprovecharte de la opción del no desplazamiento que permite el teletrabajo</h5>

# %% [markdown]
# <h4>Consumir energía renovable</h4>
# <h5>Una de las ventajas ambientales de las energías renovables es que no emiten CO2. Los consumidores pueden hacer uso de ellas al instalar en su casa un sistema de autoconsumo con paneles solares o al contratar alguna de las cada vez más numerosas empresas comercializadoras de electricidad renovable.</h5>
