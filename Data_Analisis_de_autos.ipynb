# %% [markdown]
# <center><img SRC="imag.png"/></center>
#
# <center><h1 style="color:#00FFFF"> Analisis de datos </h1></center>
# <center><h4 style="color:#6495ED"> U.Castro Carazo </h5></center>
# <center><h6 style="color:#6495ED"> II Cuatrimestre </h6></center>
# </br>
# </br>
# <p Style="text-aling: justify">La empresa PK2, especialista en venta de vehiculos usados, desea conocer cual es la distribucion y costo de los autos que tienen actualmente en inventario, para la venta.
#
# La pregunta de negocio para responder es: ¿cual es estrategia podria implementar para generar una mayor rotacionde inventario?
#
# El objetivo principal, es poder proponer una estrategia de venta de carros en funcion de los disponibles en el lote actual.</p>
#
# <!-- para escribir comentarios -->
# <p style = "font-weight:bold"> la fuente para cambiar los colores del texto es:</p>
# <a href="https://www.w3schools.com/html/html_links.asp">W3SCHOOLS</a>

# %% [markdown]
# # <h2 style="color:#FF7F50">1. Carga y estandarizacion de los archivos de datos </h2>
#
# <p style="color:#FF7F50">
# <p style="font-weight: bold"> Que se hace en este apartado? </p></p>
#
# <ol style="list-style-type:lower-alpha">
#     <li>Importar las librerias a utilizar </li>
#     <li>Importar los set de datos (XLSX, CSV, TXT, SQL, ORACLE) </li>
#     <li>Revision de los nombres de las columnas del set de datos</li>
#     <li>si tenemos mas de 1 archivo, vamos a unirlos en un unico datafreame </li>
# </ol>

# %% [markdown]
# <h3 style="color:#B8860B">a. Importar las librerias a utilizar</h3>

# %%
#Se realiza las importaciones de las librerias necesarias para el ejerecicio de analisis de datos, sobre los autos disponibles.

import pandas as pd             #para manejo de los datos -DataFrame-
import numpy as np              #para el manejo de estructuras de datos -Listas_
import matplotlib.pyplot as plt #para la creacion de los graficos

# %%
# df_nombvariable
# df_nombvariable.head(n)                            = Devuelve las n primeras filas del DataFrame df  
# df_nombvariable.shape                              = Devuelve una tupla con el número de filas y columnas del DataFrame
# df_nombvariable.columns                            = Devuelve una tupla con el número de filas y columnas del DataFrame
# df_nombvariable.tail(n)                            = Devuelve las n últimas filas del DataFrame
# df_nombvariable.describe()                         = Devuelve un DataFrame con un resumen estadístico de las columnas 
# df_nombvariable.info()                             = Devuelve información (número de filas, número de columnas, índices, tipo de las columnas y memoria usado) sobre el DataFrame
# unionArchivos = [df_nombvariable1, df_nombvariable2] = creacion de una lista de dos set de datos
# df_nuevaVarialbe = pd.concat(unionArchivos)          = luego de la creacion de las listas se procede a unir los dos set de datos

# %% [markdown]
# <h3 style="color:#B8860B">b. Importar el Set de datos</h3>
#
# <p Style="color:#6A5ACD">La fuente de los datos es la pagina denominada Machine Learning Repository, en esta se puede obtener el nombre de los encabezados del set de datos. </p>
#
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile">Fuente de datos</a>

# %%
#Se crea una lista con los nombres de las columnas.
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price" ]

#Se cargan los set de datos en la memoria de la PC.
df_autos1 = pd.read_csv("autos1.csv", names = cols)
df_autos2 = pd.read_csv("autos.csv", names = cols)

# %%
df_autos1
# Out:
#     symboling normalized        make    fuel aspiration doors      style  \
# 0           0        106      nissan     gas        std  four      sedan
# 1           0        128      nissan     gas        std  four      sedan
# 2           0        108      nissan     gas        std  four      wagon
# 3           0        108      nissan     gas        std  four      sedan
# 4           3        194      nissan     gas        std   two  hatchback
# ..        ...        ...         ...     ...        ...   ...        ...
# 92          0          ?  volkswagen  diesel      turbo  four      sedan
# 93          0          ?  volkswagen     gas        std  four      wagon
# 94         -2        103       volvo     gas        std  four      sedan
# 95         -1         74       volvo     gas        std  four      wagon
# 96         -2        103       volvo     gas        std  four      sedan
#
#    wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_autos1.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0          ?  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
df_autos2
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
# ...

# %%
df_autos2.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2          ?         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1          ?         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0          ?         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %%
df_autos1.shape
# Out:
# (97, 26)

# %%
df_autos2.shape
# Out:
# (197, 26)

# %% [markdown]
# <h3 style="color:#B8860B">c. Revision las columnas</h3>
# Este Comando permite consultar los nombres de las Columnas

# %%
df_autos2.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos1.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos1.head(15)  #las consultas se hacen entre las primeras 15 o 30 filas
# Out:
#     symboling normalized    make    fuel aspiration doors      style wheels  \
# 0           0        106  nissan     gas        std  four      sedan    fwd
# 1           0        128  nissan     gas        std  four      sedan    fwd
# 2           0        108  nissan     gas        std  four      wagon    fwd
# 3           0        108  nissan     gas        std  four      sedan    fwd
# 4           3        194  nissan     gas        std   two  hatchback    rwd
# 5           3        194  nissan     gas      turbo   two  hatchback    rwd
# 6           1        231  nissan     gas        std   two  hatchback    rwd
# 7           0        161  peugot     gas        std  four      sedan    rwd
# 8           0        161  peugot  diesel      turbo  four      sedan    rwd
# 9           0          ?  peugot     gas        std  four      wagon    rwd
# 10          0          ?  peugot  diesel      turbo  four      wagon    rwd
# ...

# %%
#1 - lo primero que se debe de hacer en la revision es verificar si lo registrado en cada columna corresponde al tipo 
#  de dato que tenemos segun la meta data.

# %% [markdown]
# <h3 style="color:#E9967A">Revision y Validadion de las Variables</h3>
# <p>Este proceso de revision permite identificar variables o datos que deben ser analizados de manera independiente ya que no concuerdan con el rango de inforamcion a contener.</p>
#
# <center><p style="color:#F0E68C" >Se requiere como insumo disponer de los Meta Datos</p></center>
# </br>

# %%
df_autos1.tail(10)  # Busca los ultimos 10 registros
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 87          2         94  volkswagen  diesel      turbo  four        sedan
# 88          2         94  volkswagen     gas        std  four        sedan
# 89          3          ?  volkswagen     gas        std   two  convertible
# 90          3        256  volkswagen     gas        std   two    hatchback
# 91          0          ?  volkswagen     gas        std  four        sedan
# 92          0          ?  volkswagen  diesel      turbo  four        sedan
# 93          0          ?  volkswagen     gas        std  four        wagon
# 94         -2        103       volvo     gas        std  four        sedan
# 95         -1         74       volvo     gas        std  four        wagon
# 96         -2        103       volvo     gas        std  four        sedan
#
#    wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
#Todos los datos NUMERICO nos sirve para darnos Estadisticas Descriptivas

# %%
df_autos1.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  97.000000   97.000000   97.000000  97.000000  97.000000    97.000000
# mean    0.855670   98.823711  175.208247  65.872165  54.194845  2587.175258
# std     1.314896    5.332170   10.064062   1.655719   2.416755   412.305914
# min    -2.000000   89.500000  156.900000  63.400000  49.700000  1918.000000
# 25%     0.000000   95.700000  168.900000  64.400000  52.500000  2261.000000
# 50%     0.000000   97.300000  173.500000  65.600000  54.500000  2535.000000
# 75%     2.000000  100.400000  183.500000  66.600000  56.000000  2975.000000
# max     3.000000  114.200000  198.900000  72.300000  59.800000  3485.000000
#
#        engine-size       bore     stroke  compression       City     Higway
# count    97.000000  97.000000  97.000000    97.000000  97.000000  97.000000
# mean    125.432990   3.388969   3.169381    10.570206  25.185567  30.814433
# ...

# %%
# Count = cantidad de registros que el campo pudo contar
# mean  =
# std   =
# min   = Valor minimo
# 25%   =
# 50%   =
# 75%   =
# max   = Valor minimo

# %%
#para saber como las cargo python
df_autos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    97 non-null     int64
#  1   normalized   97 non-null     object
#  2   make         97 non-null     object
#  3   fuel         97 non-null     object
#  4   aspiration   97 non-null     object
#  5   doors        97 non-null     object
#  6   style        97 non-null     object
#  7   wheels       97 non-null     object
#  8   engine       97 non-null     object
#  9   base         97 non-null     float64
#  10  length       97 non-null     float64
#  11  width        97 non-null     float64
#  12  heingt       97 non-null     float64
#  13  curb         97 non-null     int64
#  14  engineType   97 non-null     object
#  15  Cylinders    97 non-null     object
#  16  engine-size  97 non-null     int64
#  17  system       97 non-null     object
# ...

# %% [markdown]
# <h3 style="color:#B8860B"> d. Unir los Set de datos </h3>

# %%
# df_autos1 - 97 observaciones y 26 columnas
# df_autos2 - 197 observaciones y 26 columnas
# para poder unir dos set de datos es importante que el numero de columnas sean iguales

unionArchivos = [df_autos1, df_autos2] #se esta creando una lista del dataframe
df_Autos = pd.concat(unionArchivos)    #creacion de la nueva variable utilizando concat(concatenar)
df_Autos.shape
# Out:
# (294, 26)

# %% [markdown]
# # <h2 style="color:#FF7F50">2. Manejo de Varlores Faltantes </h2>
#
# <p style="color:#FF7F50">
# <p style="font-weight: bold"> Que se hace en este apartado? </p></p>
#
# <ol>
#     <li>Identificar como se muestras los valores faltantes y estandarizarlos a Nan </li>
#     <li>Contar la cantidad de valores NaN (faltantes)</li>
#     <li>Analisis para imputar los Valores numericos con la media </li>
#     <li>Analisis para imputar los Valores caracter como el mas frecuente</li>
#     <li>Eliminar filas con valores faltantes</li>
# </ol>

# %% [markdown]
# <h3 style="color:#B8860B">1. Identificar como se muestras los valores faltantes y estandarizarlos a Nan</h3>

# %%
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0          ?  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
df_Autos.replace("?",np.nan,inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        NaN  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# <h5 Style= "color:#556b2f">2.2 Contar la cantidad de Valores NaN(faltantes)</h5>

# %%
valoresPerdidos =df_Autos.isnull()
valoresPerdidos.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False       False  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False       False  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# ...

# %%
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print(" ")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    237
# True      57
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    292
# True       2
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h5 Style= "color:#556b2f">2.3 Analisis para imputar los Valores numericos con la media</h5>

# %%
avg_norm = df_Autos["normalized"].astype("float").mean(axis=0)
print("la media de normalized es: ",avg_norm)
# Out:
# la media de normalized es:  122.26160337552743

# %%
df_Autos["normalized"].replace(np.nan,122, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
df_Autos["bore"].replace(np.nan, 3.22, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
avg_norm=df_Autos["peak"].astype("float").mean(axis=0)
print("la media de normalized es: ",avg_norm)
# Out:
# la media de normalized es:  5087.931034482759

# %%
df_Autos["peak"].replace(np.nan, 5088, inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# <h5 Style= "color:#556b2f">2.4 Analisis para imputar los Valores caracter como el mas frecuente</h5>

# %%
df_Autos["doors"].value_counts()
# Out:
# four    167
# two     125
# Name: doors, dtype: int64

# %%
df_Autos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df_Autos["doors"].replace(np.nan, "four", inplace=True)
df_Autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %%
df_Autos["stroke"].replace(np.nan, 4.17, inplace=True)
df_Autos["horsepower"].replace(np.nan, 288, inplace=True)
df_Autos["price"].replace(np.nan, 45500, inplace=True)

# %%
valoresPerdidos =df_Autos.isnull()
for column in valoresPerdidos.columns.values.tolist():
    print(column)
    print(valoresPerdidos[column].value_counts())
    print(" ")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    294
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    294
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# False    294
# ...

# %% [markdown]
# <h5 Style= "color:#556b2f">2.5 Eliminar filas con valores faltantes</h5>

# %%
#df_Autos.dropna(subset= ("price"), axis=0, inplace=True)
#df_Autos

# %%
df_Autos.reset_index(drop=True, inplace=True)
df_Autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 289          0        122  volkswagen  diesel      turbo  four      sedan
# 290          0        122  volkswagen     gas        std  four      wagon
# 291         -2        103       volvo     gas        std  four      sedan
# 292         -1         74       volvo     gas        std  four      wagon
# 293         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
#SESION 18072022

# %% [markdown]
# <h3 style="color:#000080">3. Estandarizar de Datos </h3>
# <p style="color:#FF7F50">
# <p style="font-weight: bold"> Que se hace en este Etapa? </p></p>
#
# <ol>
#     <li>Verificar el Dominio de las Variables y se ajusta, si es necesario </li>
#     <li>Convertir valores en funcion de la interpretacion</li>
#     <li>Normalizar los datos para que sus valores queden entre 0 y 1 </li>
#     <li>Agrupar datos (Binning)</li>
#
# </ol>

# %% [markdown]
# <h4 style="color:#000080"> 3.1 Verificar el Dominio de las Variables </h4>

# %%
df_Autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          0        106  nissan  gas        std  four      sedan    fwd
# 1          0        128  nissan  gas        std  four      sedan    fwd
# 2          0        108  nissan  gas        std  four      wagon    fwd
# 3          0        108  nissan  gas        std  four      sedan    fwd
# 4          3        194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# ...

# %%
df_Autos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
## Esto se realiza para poder estandarizar los tipos de datos del negocio, no es necesario hacerlo siempre
#df_Autos.dropna(subset =("horsepower"),axis=0,inplace=True)
#df_Autos.dropna(subset =("normalized"),axis=0,inplace=True)
#df_Autos.reset_index(drop=True,inplace=True)

df_Autos[['bore','stroke','peak']]= df_Autos[['bore','stroke','peak']].astype('float')
df_Autos[['price']] = df_Autos[['price']].astype('float')
df_Autos[['normalized','horsepower']] = df_Autos[['normalized','horsepower']].astype('float')
df_Autos.dtypes
# Out:
# symboling        int64
# normalized     float64
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower     float64
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h4 style="color:#000080"> 3.2 Estandarizar Valores </h4>

# %%
df_Autos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors  style wheels engine  \
# 0          0       106.0  nissan  gas        std  four  sedan    fwd  front
# 1          0       128.0  nissan  gas        std  four  sedan    fwd  front
# 2          0       108.0  nissan  gas        std  four  wagon    fwd  front
#
#     base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0   97.2  ...          120    2bbl  3.33    3.47         8.5       97.0
# 1  100.4  ...          181    mpfi  3.43    3.27         9.0      152.0
# 2  100.4  ...          181    mpfi  3.43    3.27         9.0      152.0
#
#      peak City  Higway    price
# 0  5200.0   27      34   9549.0
# 1  5200.0   17      22  13499.0
# 2  5200.0   17      22  14399.0
#
# [3 rows x 26 columns]

# %%
df_Autos['city-L/100km'] =235/df_Autos['City']
df_Autos['higway-L/100km'] =235/df_Autos['Higway']
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0       106.0  nissan  gas        std  four      sedan    fwd
# 1          0       128.0  nissan  gas        std  four      sedan    fwd
# 2          0       108.0  nissan  gas        std  four      wagon    fwd
# 3          0       108.0  nissan  gas        std  four      sedan    fwd
# 4          3       194.0  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  bore  stroke  compression  horsepower    peak City  \
# 0  front   97.2  ...  3.33    3.47          8.5        97.0  5200.0   27
# 1  front  100.4  ...  3.43    3.27          9.0       152.0  5200.0   17
# 2  front  100.4  ...  3.43    3.27          9.0       152.0  5200.0   17
# 3  front  100.4  ...  3.43    3.27          9.0       152.0  5200.0   19
# 4  front   91.3  ...  3.43    3.27          9.0       160.0  5200.0   19
#
#    Higway    price  city-L/100km  higway-L/100km
# ...

# %% [markdown]
# <h4 style="color:#000080"> 3.3 Normalizar Valores </h4>

# %%
dfTemp=df_Autos[['length','width','heingt']]
dfTemp
# Out:
#      length  width  heingt
# 0     173.4   65.2    54.7
# 1     181.7   66.5    55.1
# 2     184.6   66.5    56.1
# 3     184.6   66.5    55.1
# 4     170.7   67.9    49.7
# ..      ...    ...     ...
# 289   180.2   66.9    55.1
# 290   183.1   66.9    55.1
# 291   188.8   67.2    56.2
# 292   188.8   67.2    57.5
# 293   188.8   67.2    56.2
#
# [294 rows x 3 columns]

# %%
df_Autos["length"]=df_Autos['length']/df_Autos['length'].max()
df_Autos["width"]=df_Autos['width']/df_Autos['width'].max()
df_Autos["heingt"]=df_Autos['heingt']/df_Autos['heingt'].max()

# %%
dfTemp=df_Autos[['length','width','heingt']]
dfTemp
# Out:
#        length     width    heingt
# 0    0.833253  0.901798  0.914716
# 1    0.873138  0.919779  0.921405
# 2    0.887074  0.919779  0.938127
# 3    0.887074  0.919779  0.921405
# 4    0.820279  0.939142  0.831104
# ..        ...       ...       ...
# 289  0.865930  0.925311  0.921405
# 290  0.879865  0.925311  0.921405
# 291  0.907256  0.929461  0.939799
# 292  0.907256  0.929461  0.961538
# 293  0.907256  0.929461  0.939799
#
# [294 rows x 3 columns]

# %% [markdown]
# <h3 style="color:#000080">3.4 Agrupar Datos Binning</h3>

# %%
df_Autos
# Out:
#      symboling  normalized        make    fuel aspiration doors      style  \
# 0            0       106.0      nissan     gas        std  four      sedan
# 1            0       128.0      nissan     gas        std  four      sedan
# 2            0       108.0      nissan     gas        std  four      wagon
# 3            0       108.0      nissan     gas        std  four      sedan
# 4            3       194.0      nissan     gas        std   two  hatchback
# ..         ...         ...         ...     ...        ...   ...        ...
# 289          0       122.0  volkswagen  diesel      turbo  four      sedan
# 290          0       122.0  volkswagen     gas        std  four      wagon
# 291         -2       103.0       volvo     gas        std  four      sedan
# 292         -1        74.0       volvo     gas        std  four      wagon
# 293         -2       103.0       volvo     gas        std  four      sedan
#
# ...

# %%
df_Autos[['horsepower']] = df_Autos[['horsepower']].astype('int')
df_Autos.dtypes
# Out:
# symboling           int64
# normalized        float64
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower          int32
# peak              float64
# City                int64
# Higway              int64
# price             float64
# city-L/100km      float64
# higway-L/100km    float64
# dtype: object

# %%
bins=np.linspace(min(df_Autos["horsepower"]),max(df_Autos["horsepower"]), 4)
bins
# Out:
# array([ 48., 128., 208., 288.])

# %%
nombre=["pequeño","mediano","grande"]
df_Autos["horsepower-bins"]=pd.cut(df_Autos["horsepower"],bins,labels=nombre, include_lowest=True)
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0       106.0  nissan  gas        std  four      sedan    fwd
# 1          0       128.0  nissan  gas        std  four      sedan    fwd
# 2          0       108.0  nissan  gas        std  four      wagon    fwd
# 3          0       108.0  nissan  gas        std  four      sedan    fwd
# 4          3       194.0  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
df_Autos[["horsepower","horsepower-bins"]].head(10)
# Out:
#    horsepower horsepower-bins
# 0          97         pequeño
# 1         152         mediano
# 2         152         mediano
# 3         152         mediano
# 4         160         mediano
# 5         200         mediano
# 6         160         mediano
# 7          97         pequeño
# 8          95         pequeño
# 9          97         pequeño

# %%
df_Autos[["horsepower-bins"]].value_counts()
# Out:
# horsepower-bins
# pequeño            233
# mediano             54
# grande               7
# dtype: int64

# %%
plt.hist(df_Autos["horsepower-bins"])
plt.xlabel('Categoria')
plt.ylabel('Cantidad Autos')
plt.title('Cantidad de Autos segun caballos de Fuerza')
plt.show()

# %%
df_Autos
# Out:
#      symboling  normalized        make    fuel aspiration doors      style  \
# 0            0       106.0      nissan     gas        std  four      sedan
# 1            0       128.0      nissan     gas        std  four      sedan
# 2            0       108.0      nissan     gas        std  four      wagon
# 3            0       108.0      nissan     gas        std  four      sedan
# 4            3       194.0      nissan     gas        std   two  hatchback
# ..         ...         ...         ...     ...        ...   ...        ...
# 289          0       122.0  volkswagen  diesel      turbo  four      sedan
# 290          0       122.0  volkswagen     gas        std  four      wagon
# 291         -2       103.0       volvo     gas        std  four      sedan
# 292         -1        74.0       volvo     gas        std  four      wagon
# 293         -2       103.0       volvo     gas        std  four      sedan
#
# ...

# %% [markdown]
# <h3 style="color:#000080">4. Visualizacion de Datos </h3>
# <p style="color:#FF7F50">
# <p style="font-weight: bold"> En este apartado se van a crear diferentes visualizaciones(Graficas), las cuales nos ayudan a realizar la interpretacion y analisis de la informacion del set </p>
#
# <p style="font-weight: bold"> Estos son tres elementos fuandamentales para poder crear las visualizaciones </p>
#
# <ol>
#     <li>Preguntas de negocio a responder</li>
#     <li>pleno conocimiento del set de datos</li>
#     <li>Experiencia de negocios </li>
#
#
# </ol>

# %%
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0       106.0  nissan  gas        std  four      sedan    fwd
# 1          0       128.0  nissan  gas        std  four      sedan    fwd
# 2          0       108.0  nissan  gas        std  four      wagon    fwd
# 3          0       108.0  nissan  gas        std  four      sedan    fwd
# 4          3       194.0  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
df_Autos[['make']].value_counts()
# Out:
# make
# toyota           64
# nissan           25
# volkswagen       24
# subaru           24
# peugot           22
# mazda            17
# plymouth         14
# mitsubishi       13
# honda            13
# saab             12
# porsche          10
# dodge             9
# bmw               8
# mercedes-benz     8
# audi              7
# volvo             6
# renault           4
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# mercury           1
# dtype: int64

# %%
#Agrupar las observaciones segun marca de vehiculo
gf1= df_Autos.groupby(['make']).count()
gf1=gf1.iloc[:,:1]
gf1
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   7
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  4
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                25
# peugot                22
# plymouth              14
# porsche               10
# renault                4
# saab                  12
# subaru                24
# toyota                64
# volkswagen            24
# volvo                  6

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf1 = df_Autos.groupby(['make']).count()
gf1 = gf1.iloc[:,:1]
#gf1=df_Autos.rename(columns={'make':'Marca'}
gf1
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   7
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  4
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                25
# peugot                22
# plymouth              14
# porsche               10
# renault                4
# saab                  12
# subaru                24
# toyota                64
# volkswagen            24
# volvo                  6

# %%
marcas=('alfa-romero',
'audi',
'bmw',
'chevrolet',
'dodge',
'honda',
'isuzu',
'jaguar',
'mazda',
'mercedes-benz',
'mercury',
'mitsubishi',
'nissan',
'peugot',
'plymouth',
'porsche',
'renault',
'saab',
'subaru',
'toyota',
'volkswagen',
'volvo')

eje_y = gf1['symboling'].tolist()

plt.rcdefaults()

fig, ax = plt.subplots()

y_pos = np.arange(len(marcas))

plt.barh(y_pos, eje_y, align='center',height=0.8, color= "#006400", alpha=1)

plt.yticks(y_pos, labels=marcas)
#plt.invert_yaxis()  # labels read top-to-bottom
plt.xlabel('Cantidad de Vehiculos').set_color("#006400")
plt.title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf2 = df_Autos.groupby(['style']).count()
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# hatchback          101
# sedan              131
# wagon               40

# %%
eje_y =gf2['symboling'].tolist()
plt.rcdefaults()

fig, ax = plt.subplots()

estilo=('convertible','hardtop','hatchback','sedan','wagon')

y_pos =np.arange(len(estilo))

plt.barh(y_pos, eje_y, align='center',height=0.8, color= "#006400", alpha=1)
plt.yticks(y_pos, labels=estilo)
#plt.invert_yaxis()
plt.xlabel('Cantidad de Vehiculos').set_color("#006400")
plt.title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf3 = df_Autos.groupby(['horsepower-bins']).count()
gf3 = gf3.iloc[:,:1]
gf3
# Out:
#                  symboling
# horsepower-bins
# pequeño                233
# mediano                 54
# grande                   7

# %%
marcas = ("Pequeno", "Mediano","Grande")

eje_y = gf3['symboling'].tolist()

#Creamos la grafica
plt.bar(marcas, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("Marca de Vehiculos")

##Titulo del Grafico
plt.title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf4 = df_Autos.groupby(['style']).count()
gf4 = gf4.iloc[:,:1]

#Codigo para ordenar los valores ascendente y desendente
#gf4 = gf4.sort_values('symboling') #Ordena de Menor a Mayor
gf4 = gf4.sort_values('symboling',ascending=False) #Ordena de Mayor a Menor
gf4
# Out:
#              symboling
# style
# sedan              131
# hatchback          101
# wagon               40
# hardtop             13
# convertible          9

# %%
#Codigo para obtener la lista del indice del DataFrame
eje_x = gf4.index.tolist()

eje_y = gf4['symboling'].tolist()

#Creamos la grafica
plt.bar(eje_x, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("estilo de Vehiculos")

##Titulo del Grafico
plt.title('Cantidad de autos segun estilo')

plt.show()

# %%
df_Autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0       106.0  nissan  gas        std  four      sedan    fwd
# 1          0       128.0  nissan  gas        std  four      sedan    fwd
# 2          0       108.0  nissan  gas        std  four      wagon    fwd
# 3          0       108.0  nissan  gas        std  four      sedan    fwd
# 4          3       194.0  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
gf5 = df_Autos.groupby(['doors']).count()
gf5 = gf5.iloc[:,:1]
gf5
# Out:
#        symboling
# doors
# four         169
# two          125

# %%
etiquetas = gf5.index.tolist()
sizes = gf5['symboling'].tolist()
separacion=(0,0.1)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=separacion, labels=etiquetas, autopct='%1.0f%%', shadow = True, startangle=90)
ax1.axis('equal')
plt.show()

# %%
gf5 = df_Autos.groupby(['style']).count()
gf5 = gf5.iloc[:,:1]
gf5 = gf5.sort_values('symboling') #Ordena de Menor a Mayor
gf5
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# wagon               40
# hatchback          101
# sedan              131

# %%
fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

data = gf5['symboling']
estilo = gf5.index.tolist()


def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.0f}%".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
                                  

ax.legend(wedges, estilo,
          title="Estilos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=6, weight="bold")

ax.set_title("Porcentaje de Vehiculos segun estilos")

plt.show()

# %%
#colores del grafico 218C8D 6CCECB F9E559 EF7126 8EDC9D
#https://www.colorcombos.com/                   ////pagina para colores
#https://color.adobe.com/es/create/color-wheel ////pagina para colores



colores=['#218C8D','#6CCECB', '#F9E559', '#EF7126', '#8EDC9D']

#separaciones
separacion = (0.01,0.01,0.01,0.01,0.01)

#creacion grafica circular
plt.pie(data, explode=separacion, labels=estilo, autopct='%1.0f%%', pctdistance = 0.90, colors=colores )

#Dibujar Circulo blanco
circulo = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(circulo)

plt.title("Porcentaje de Vehiculos segun estilos")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_Autos[['price', 'city-L/100km']].head(5)
# Out:
#      price  city-L/100km
# 0   9549.0      8.703704
# 1  13499.0     13.823529
# 2  14399.0     13.823529
# 3  13499.0     12.368421
# 4  17199.0     12.368421

# %%
import matplotlib.cbook as cbook



fig, ax = plt.subplots()
ax.scatter(df_Autos['price'], df_Autos['city-L/100km'], s=df_Autos['horsepower'], alpha=0.5)

ax.set_xlabel('Precio', fontsize=15)
ax.set_ylabel('Consumo Combustible en ciudad', fontsize=15)
ax.set_title('Correlacion Precio vs consumo de combustible en ciudad')

ax.grid(True)
fig.tight_layout()

plt.show()
